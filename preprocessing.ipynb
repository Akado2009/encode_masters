# %%
import os
import numpy as np
import pandas as pd

# %%
DATA_DIR = "data"

# %%
meta_table = pd.read_table(os.path.join(DATA_DIR, "metadata.tsv"))
# Out:
# /mnt/c/Users/kprosvir/Desktop/masters/env/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.

# %%
meta_fold_change = meta_table[meta_table["Output type"] == "fold change over control"]

# %%
meta_table.columns
# Out:
# Index(['File accession', 'File format', 'Output type', 'Experiment accession',
#        'Assay', 'Biosample term id', 'Biosample term name', 'Biosample type',
#        'Biosample organism', 'Biosample treatments',
#        'Biosample treatments amount', 'Biosample treatments duration',
#        'Biosample genetic modifications methods',
#        'Biosample genetic modifications categories',
#        'Biosample genetic modifications targets',
#        'Biosample genetic modifications gene targets',
#        'Biosample genetic modifications site coordinates',
#        'Biosample genetic modifications zygosity', 'Experiment target',
#        'Library made from', 'Library depleted in', 'Library extraction method',
#        'Library lysis method', 'Library crosslinking method',
#        'Library strand specific', 'Experiment date released', 'Project',
#        'RBNS protein concentration', 'Library fragmentation method',
# ...

# %%
meta_table.head()
# Out:
#   File accession        File format               Output type  \
# 0    ENCFF409RWY             bigWig            signal p-value
# 1    ENCFF655FOD             bigWig  fold change over control
# 2    ENCFF669LJR     bed narrowPeak                     peaks
# 3    ENCFF945OSD     bed narrowPeak                     peaks
# 4    ENCFF297WYL  bigBed narrowPeak                     peaks
#
#   Experiment accession     Assay Biosample term id Biosample term name  \
# 0          ENCSR571IIS  ChIP-seq       EFO:0003042             H1-hESC
# 1          ENCSR571IIS  ChIP-seq       EFO:0003042             H1-hESC
# 2          ENCSR571IIS  ChIP-seq       EFO:0003042             H1-hESC
# 3          ENCSR571IIS  ChIP-seq       EFO:0003042             H1-hESC
# 4          ENCSR571IIS  ChIP-seq       EFO:0003042             H1-hESC
#
#   Biosample type Biosample organism  Biosample treatments  ...  \
# 0      cell line       Homo sapiens                   NaN  ...
# ...
